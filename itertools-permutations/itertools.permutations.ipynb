# %%
from IPython.display import Image
Image("/Users/tpalczew/Desktop/perm1.png")

# %%
from IPython.display import Image
Image("/Users/tpalczew/Desktop/perm2.png")

# %%
import itertools
st, k = (input().split(" "))
st = list(st)
st = sorted(st)
k = int(k)

perm = itertools.permutations(st, k)

for elem in perm:
    elem = ''.join(map(str,elem))
    print(elem)
# Out:
# HACK 2
# AC
# AH
# AK
# CA
# CH
# CK
# HA
# HC
# HK
# KA
# KC
# KH
