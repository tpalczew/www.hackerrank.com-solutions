# %%
from IPython.display import Image
Image("/Users/tpalczew/Desktop/CompanyLogo1.png")

# %%
from IPython.display import Image
Image("/Users/tpalczew/Desktop/CompanyLogo2.png")

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

from collections import OrderedDict
from collections import Counter
import operator

d = OrderedDict()
if __name__ == '__main__':
    s = input()
    s = list(s)
    
    for elem in s:
        d[elem] = d.get(elem, 0) + 1
    
    dd = OrderedDict(sorted(d.items(), key=lambda x: x[0])) # delete if you want to keep the order and don't want to sort

    v=list(dd.values())
    ind=list(dd.keys())


    for elem in range(3):
        maxv = max(v) 
        vindi = v.index(maxv)
        print( str( ind[vindi] ) + " " + str( v[vindi]))
        del v[vindi]
        del ind[vindi]
# Out:
# aabbbccde
# b 3
# a 2
# c 2
