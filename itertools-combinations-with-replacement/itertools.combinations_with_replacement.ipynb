# %%
from IPython.display import Image
Image("/Users/tpalczew/Desktop/combwr1.png")

# %%
from IPython.display import Image
Image("/Users/tpalczew/Desktop/combwr2.png")

# %%
text, k = input().split(" ")
k = int(k)
text = sorted(text)

from itertools import combinations_with_replacement as cwr

combwr = cwr(text, k)
for elem in combwr:
    elem = "".join(elem)
    print(elem)
# Out:
# HACK 2
# AA
# AC
# AH
# AK
# CC
# CH
# CK
# HH
# HK
# KK
