# %%
from IPython.display import Image
Image(filename='/Users/tpalczew/HackerRank/compute_hash_tuple.png')

# %%
if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')
    def test_all():
        nd = input()
        integer_list = map(int, nd.split())
        print((hash(tuple(integer_list))))

# %%
test_all()
# Out:
# 1 23 45 2
# -6512378398476671148

# %%
test_all()
# Out:
# 1 2
# 3713081631934410656
