# %%
from IPython.display import Image
Image(filename='/Users/tpalczew/HackerRank/ArithmeticOperators.png')

# %%
if __name__ == '__main__':
    a = int(input())
    b = int(input())
    
    print(a+b)
    print(a-b)
    print(a*b)
# Out:
# 120
# 123
# 243
# -3
# 14760

# %%
def do_this_arithmetic_ops(a, b):
    a = int(a)
    b = int(b)
    return (a+b), (a-b), (a*b)

# %%
do_this_arithmetic_ops(120,123)
# Out:
# (243, -3, 14760)

# %%
do_this_arithmetic_ops(3,2)
# Out:
# (5, 1, 6)
