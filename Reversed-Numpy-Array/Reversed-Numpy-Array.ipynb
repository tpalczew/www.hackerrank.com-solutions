# %%
from IPython.display import Image
Image("/Users/tpalczew/Desktop/arrays.png")

# %%
import numpy

def arrays(arr):
    # complete this function
    # use numpy.array
    arr = (arr[::-1])
    arr = numpy.array(arr,float)
    return arr

# %%
arrays([1,2,3,4,5])
# Out:
# array([5., 4., 3., 2., 1.])
