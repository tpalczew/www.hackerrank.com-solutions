# %%
from IPython.display import Image
Image(filename='/Users/tpalczew/HackerRank/RotationLeft.png')

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

# Complete the rotLeft function below.
def rotLeft(a, d):
    return a[d:] + a[:d]

def rotRight(a, d):
    return a[-d:] + a[:-d]


def rotateLeft(a, d):
    if len(a) == 0:
        return a
    d = d % len(a)     # left direction
    return a[d:] + a[:d]


def rotateRight(a, d):
    if len(a) == 0:
        return a
    d = -d % len(a)     # right direction
    return a[d:] + a[:d]


if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')

    def test_all():
        
        nd = input().split()
        
        try:
            int(nd[0])
        except ValueError as err1:
            print("not an integer")
            return("I need integer")
            
        try:
            int(nd[1])
        except ValueError as err2:
            print("not an integer")
            return("I need integer")
        
        n = int(nd[0])
        d = int(nd[1])
        try:
            a = list(map(int, input().rstrip().split()))
        except ValueError as err3:
            return("I need integers")
    
        try:
            result = rotLeft(a, d)
            print("Left rotation = " + str(result))
        except:
            print("Error - rotLeft")
    
        try:
            result2 = rotRight(a, d)
            print("Right rotation = " + str(result2))
        except:
            print("Error - rotRight")
    
        try:
            result3 = rotateLeft(a, d)
            print("Left rotation = " + str(result3))
        except:
            print("Error - rotateLeft")
    
        try:
            result4 = rotateRight(a, d)
            print("Right rotation = " + str(result4))
        except:
            print("Error - rotateRight")

    
    #fptr.write(' '.join(map(str, result)))
    #fptr.write('\n')

    #fptr.close()

# %%
test_all()
# Out:
# 1 2
# 1 2 3 4 5 6 7 8 9
# Left rotation = [3, 4, 5, 6, 7, 8, 9, 1, 2]
# Right rotation = [8, 9, 1, 2, 3, 4, 5, 6, 7]
# Left rotation = [3, 4, 5, 6, 7, 8, 9, 1, 2]
# Right rotation = [8, 9, 1, 2, 3, 4, 5, 6, 7]

# %%
test_all()
# Out:
# 1 5
# 1 2 3 4 5 6 7 8 9
# Left rotation = [6, 7, 8, 9, 1, 2, 3, 4, 5]
# Right rotation = [5, 6, 7, 8, 9, 1, 2, 3, 4]
# Left rotation = [6, 7, 8, 9, 1, 2, 3, 4, 5]
# Right rotation = [5, 6, 7, 8, 9, 1, 2, 3, 4]

# %%
test_all()
# Out:
# 1 1
# 1
# Left rotation = [1]
# Right rotation = [1]
# Left rotation = [1]
# Right rotation = [1]

# %%
test_all()
# Out:
# 1 1
#
# Left rotation = []
# Right rotation = []
# Left rotation = []
# Right rotation = []

# %%
test_all()
# Out:
# 4 2
# 1 2 3 4 5 6 7 8 9
# Left rotation = [3, 4, 5, 6, 7, 8, 9, 1, 2]
# Right rotation = [8, 9, 1, 2, 3, 4, 5, 6, 7]
# Left rotation = [3, 4, 5, 6, 7, 8, 9, 1, 2]
# Right rotation = [8, 9, 1, 2, 3, 4, 5, 6, 7]

# %%
test_all()
# Out:
# 0 2
# 1 2 3 4 5
# Left rotation = [3, 4, 5, 1, 2]
# Right rotation = [4, 5, 1, 2, 3]
# Left rotation = [3, 4, 5, 1, 2]
# Right rotation = [4, 5, 1, 2, 3]

# %%
test_all()
# Out:
# -100 100
# 1 23 34 2 5 6 7 8 9
# Left rotation = [1, 23, 34, 2, 5, 6, 7, 8, 9]
# Right rotation = [1, 23, 34, 2, 5, 6, 7, 8, 9]
# Left rotation = [23, 34, 2, 5, 6, 7, 8, 9, 1]
# Right rotation = [9, 1, 23, 34, 2, 5, 6, 7, 8]

# %%
test_all()
# Out:
# -2 2
# 1 2 3 4 5 6 7 8 9
# Left rotation = [3, 4, 5, 6, 7, 8, 9, 1, 2]
# Right rotation = [8, 9, 1, 2, 3, 4, 5, 6, 7]
# Left rotation = [3, 4, 5, 6, 7, 8, 9, 1, 2]
# Right rotation = [8, 9, 1, 2, 3, 4, 5, 6, 7]

# %%
test_all()
# Out:
# 1 2
#
# Left rotation = []
# Right rotation = []
# Left rotation = []
# Right rotation = []

# %%
test_all()
# Out:
# a b
# not an integer
# 'I need integer'

# %%
test_all()
# Out:
# a 2
# not an integer
# 'I need integer'

# %%
test_all()
# Out:
# 1 2
# 1 2 3 4 a 5 6 7
# 'I need integers'
