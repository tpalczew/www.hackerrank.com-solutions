# %%
from IPython.display import Image
Image("/Users/tpalczew/Desktop/html1.png")

# %%
from IPython.display import Image
Image("/Users/tpalczew/Desktop/html2.png")

# %%
from IPython.display import Image
Image("/Users/tpalczew/Desktop/html3.png")

# %%
from IPython.display import Image
Image("/Users/tpalczew/Desktop/html4.png")

# %%
from html.parser import HTMLParser

class MyHTMLParser(HTMLParser):
    def handle_starttag(self, tag, attrs):
        print("Start :", tag)
        if attrs:
            for element in attrs:
                print("-> " + str(element[0]) + " > " + str(element[1]) )

    def handle_endtag(self, tag):
        print("End   :", tag)

    def handle_startendtag(self, tag, attrs):
        print("Empty :", tag)
        if attrs:
            for element in attrs:
                print("-> " + str(element[0]) + " > " + str(element[1]) )

n = int(input())
page = []
for line in range(n):
  page.append(str(input()))

parser=MyHTMLParser()
parser.feed("\n".join(page))
# Out:
# 2
# <html><head><title>HTML Parser - I</title></head>
# <body data-modal-target class='1'><h1>HackerRank</h1><br /></body></html>
# Start : html
# Start : head
# Start : title
# End   : title
# End   : head
# Start : body
# -> data-modal-target > None
# -> class > 1
# Start : h1
# End   : h1
# Empty : br
# End   : body
# End   : html
