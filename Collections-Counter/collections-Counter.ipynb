# %%
from IPython.display import Image
Image("/Users/tpalczew/Desktop/coll1.png")

# %%
from IPython.display import Image
Image("/Users/tpalczew/Desktop/coll2.png")

# %%
from collections import Counter

number_of_s = int(input())
s_sizes = input().split(" ")
count_s_sizes = Counter(s_sizes)

final = 0
for element in range( int( input() )):
    s, p = input().split(" ")
    if count_s_sizes[s] != 0:
        final += int(p)
        count_s_sizes[s] -= 1
print(final)
# Out:
# 10
# 2 3 4 5 6 8 7 6 5 18
# 6
# 6 55
# 6 45
# 6 55
# 4 40
# 18 60
# 10 50
# 200
