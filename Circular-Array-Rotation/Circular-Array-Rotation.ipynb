# %%
from IPython.display import Image
Image(filename='/Users/tpalczew/Desktop/cra1.png')

# %%
from IPython.display import Image
Image(filename='/Users/tpalczew/Desktop/cra2.png')

# %%
from IPython.display import Image
Image(filename='/Users/tpalczew/Desktop/cra3.png')

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

from collections import deque 

# Complete the circularArrayRotation function below.
def circularArrayRotation(a, k, queries):
    res = []
    da = deque(a)
    for _ in range(k):
        da.appendleft(da.pop())
    for element in queries:
        res.append(da[element])
    return res

# %%
nkq = input().split()

n = int(nkq[0])

k = int(nkq[1])

q = int(nkq[2])

a = list(map(int, input().rstrip().split()))

queries = []

for _ in range(q):
    queries_item = int(input())
    queries.append(queries_item)

result = circularArrayRotation(a, k, queries)
# Out:
# 3 2 3
# 1 2 3
# 0
# 1
# 2

# %%
print(result)
# Out:
# [2, 3, 1]
