# %%
from IPython.display import Image
Image("/Users/tpalczew/Desktop/shape.png")

# %%
import numpy

def solution():
    inp = input()
    inp = [int(n) for n in inp if n != ' ']
    inp = numpy.array(inp)
    inp.shape = (3,3)
    return inp

# %%
inp = solution()
# Out:
# 1 2 3 4 5 6 7 8 9

# %%
print(inp)
# Out:
# [[1 2 3]
#  [4 5 6]
#  [7 8 9]]
